# %% [markdown]
# # Outros modelos

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, Lasso, LinearRegression, Ridge
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PowerTransformer,
    StandardScaler,
    QuantileTransformer,
)

from src.config import DADOS_CATEGORIZADOS
from src.modelos import organiza_resultados, treinar_e_validar_modelo_regressao

sns.set_theme(palette="bright")

RANDOM_STATE = 42

# %%
df = pd.read_parquet(DADOS_CATEGORIZADOS)

df.head()
# Out:
#    idade  sexo        imc  pressao_media  colesterol_total         ldl   hdl  \
# 0     59     2  32.099998          101.0               157   93.199997  38.0
# 1     48     1  21.600000           87.0               183  103.199997  70.0
# 2     72     2  30.500000           93.0               156   93.599998  41.0
# 3     24     1  25.299999           84.0               198  131.399994  40.0
# 4     50     1  23.000000          101.0               192  125.400002  52.0
#
#    triglicerides  glicose  target colesterol_hdl_cat
# 0         4.8598       87     151                4-5
# 1         3.8918       69      75                2-3
# 2         4.6728       85     141                4-5
# 3         4.8903       89     206                4-5
# 4         4.2905       80     135                4-5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   idade               442 non-null    int8
#  1   sexo                442 non-null    int8
#  2   imc                 442 non-null    float32
#  3   pressao_media       442 non-null    float32
#  4   colesterol_total    442 non-null    int16
#  5   ldl                 442 non-null    float32
#  6   hdl                 442 non-null    float32
#  7   triglicerides       442 non-null    float32
#  8   glicose             442 non-null    int8
#  9   target              442 non-null    int16
#  10  colesterol_hdl_cat  442 non-null    category
# dtypes: category(1), float32(5), int16(2), int8(3)
# memory usage: 12.3 KB

# %%
X = df.drop(columns="target")
y = df["target"]

# %%
colunas_power_transform = ["imc", "ldl", "hdl", "colesterol_total"]

coluna_target = ["target"]

coluna_ordinal_encoder = ["colesterol_hdl_cat"]

coluna_one_hot_encoder = ["sexo"]

colunas_standard_scaler = [
    coluna
    for coluna in df.columns
    if coluna not in colunas_power_transform + coluna_target + coluna_ordinal_encoder + coluna_one_hot_encoder
]

colunas_standard_scaler
# Out:
# ['idade', 'pressao_media', 'triglicerides', 'glicose']

# %%
categorias_ordinal_encoder = [
    ["2-3", "4-5", "6+"],
]

# %%
X.columns.difference(coluna_ordinal_encoder + coluna_one_hot_encoder)
# Out:
# Index(['colesterol_total', 'glicose', 'hdl', 'idade', 'imc', 'ldl',
#        'pressao_media', 'triglicerides'],
#       dtype='object')

# %%
preprocessamento_categoricas = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories=categorias_ordinal_encoder), coluna_ordinal_encoder),
        ("one_hot_encoder", OneHotEncoder(drop="if_binary"), coluna_one_hot_encoder),
    ],
    remainder="passthrough",
)

preprocessamento_simples = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories=categorias_ordinal_encoder), coluna_ordinal_encoder),
        ("one_hot_encoder", OneHotEncoder(drop="if_binary"), coluna_one_hot_encoder),
        ("standard_scaler", StandardScaler(), X.columns.difference(coluna_ordinal_encoder + coluna_one_hot_encoder)),
    ],
    remainder="passthrough",
)

preprocessamento_completo = ColumnTransformer(
    [
        ("power_transform", PowerTransformer(method="box-cox"), colunas_power_transform),
        ("standard_scaler", StandardScaler(), colunas_standard_scaler),
        ("ordinal_encoder", OrdinalEncoder(categories=categorias_ordinal_encoder), coluna_ordinal_encoder),
        ("one_hot_encoder", OneHotEncoder(drop="if_binary"), coluna_one_hot_encoder),
    ]
)

# %%
target_transformer = QuantileTransformer(n_quantiles=20, output_distribution="normal")

# %%
regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    
    "LinearRegression_pre_cat": {
        "preprocessor": preprocessamento_categoricas,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_pre_simples": {
        "preprocessor": preprocessamento_simples,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_pre_completo": {
        "preprocessor": preprocessamento_completo,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_pre_completo_target": {
        "preprocessor": preprocessamento_completo,
        "regressor": LinearRegression(),
        "target_transformer": target_transformer,
    },
    
    "Lasso_pre_cat": {
        "preprocessor": preprocessamento_categoricas,
        "regressor": Lasso(),
        "target_transformer": None,
    },
    "Lasso_pre_simples": {
        "preprocessor": preprocessamento_simples,
        "regressor": Lasso(),
        "target_transformer": None,
    },
    "Lasso_pre_completo": {
        "preprocessor": preprocessamento_completo,
        "regressor": Lasso(),
        "target_transformer": None,
    },
    "Lasso_pre_completo_target": {
        "preprocessor": preprocessamento_completo,
        "regressor": Lasso(),
        "target_transformer": target_transformer,
    },
    "Lasso_pre_completo_target_hiper": {
        "preprocessor": preprocessamento_completo,
        "regressor": Lasso(alpha=0.1),
        "target_transformer": target_transformer,
    },
    
    "Ridge_pre_cat": {
        "preprocessor": preprocessamento_categoricas,
        "regressor": Ridge(),
        "target_transformer": None,
    },
    "Ridge_pre_simples": {
        "preprocessor": preprocessamento_simples,
        "regressor": Ridge(),
        "target_transformer": None,
    },
    "Ridge_pre_completo": {
        "preprocessor": preprocessamento_completo,
        "regressor": Ridge(),
        "target_transformer": None,
    },
    "Ridge_pre_completo_target": {
        "preprocessor": preprocessamento_completo,
        "regressor": Ridge(),
        "target_transformer": target_transformer,
    },
    "Ridge_pre_completo_target_hiper": {
        "preprocessor": preprocessamento_completo,
        "regressor": Ridge(alpha=0.1),
        "target_transformer": target_transformer,
    },
    
    "ElasticNet_pre_cat": {
        "preprocessor": preprocessamento_categoricas,
        "regressor": ElasticNet(),
        "target_transformer": None,
    },
    "ElasticNet_pre_simples": {
        "preprocessor": preprocessamento_simples,
        "regressor": ElasticNet(),
        "target_transformer": None,
    },
    "ElasticNet_pre_completo": {
        "preprocessor": preprocessamento_completo,
        "regressor": ElasticNet(),
        "target_transformer": None,
    },
    "ElasticNet_pre_completo_target": {
        "preprocessor": preprocessamento_completo,
        "regressor": ElasticNet(),
        "target_transformer": target_transformer,
    },
    "ElasticNet_pre_completo_target_hiper": {
        "preprocessor": preprocessamento_completo,
        "regressor": ElasticNet(alpha=0.1),
        "target_transformer": target_transformer,
    },
    
}

# %%
resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

# %%
resultados
# Out:
# {'DummyRegressor': {'fit_time': array([0.00165939, 0.00145078, 0.00131822, 0.00174379, 0.00209832]),
#   'score_time': array([0.0022943 , 0.00179863, 0.00340199, 0.00245261, 0.00226927]),
#   'test_r2': array([-0.01196298, -0.02697753, -0.01530397, -0.00021233, -0.04231598]),
#   'test_neg_mean_absolute_error': array([-64.00646147, -70.57793551, -59.82954545, -70.05392912,
#          -65.42565485]),
#   'test_neg_root_mean_squared_error': array([-73.22249284, -80.04318688, -74.33859714, -82.04745226,
#          -76.3152967 ])},
#  'LinearRegression_pre_cat': {'fit_time': array([0.0122118 , 0.00797224, 0.00664997, 0.00588512, 0.00643396]),
#   'score_time': array([0.00469899, 0.0053401 , 0.0045588 , 0.00458908, 0.0047667 ]),
#   'test_r2': array([0.45229974, 0.57370343, 0.40683322, 0.58812556, 0.39131906]),
#   'test_neg_mean_absolute_error': array([-42.98079793, -41.53071359, -46.70245311, -41.89567184,
#          -47.42385671]),
#   'test_neg_root_mean_squared_error': array([-53.8683498 , -51.57031956, -56.82045789, -52.65036918,
#          -58.3185545 ])},
#  'LinearRegression_pre_simples': {'fit_time': array([0.00872421, 0.00817084, 0.00815177, 0.00752997, 0.00807977]),
#   'score_time': array([0.00562811, 0.00537729, 0.00572538, 0.0059545 , 0.00572038]),
#   'test_r2': array([0.45229974, 0.57370343, 0.40683321, 0.58812556, 0.39131907]),
#   'test_neg_mean_absolute_error': array([-42.98079751, -41.53071355, -46.70245302, -41.89567184,
#          -47.42385601]),
#   'test_neg_root_mean_squared_error': array([-53.86834947, -51.57031955, -56.82045812, -52.6503691 ,
#          -58.31855408])},
#  'LinearRegression_pre_completo': {'fit_time': array([0.0854218 , 0.09267735, 0.07553244, 0.09390974, 0.09361601]),
#   'score_time': array([0.00668621, 0.00701809, 0.00699401, 0.00753498, 0.00788808]),
#   'test_r2': array([0.44182618, 0.57230566, 0.40822371, 0.571594  , 0.38616267]),
#   'test_neg_mean_absolute_error': array([-43.64265287, -41.8973201 , -46.45066565, -42.77940995,
#          -47.84401702]),
#   'test_neg_root_mean_squared_error': array([-54.38096735, -51.65479608, -56.75381989, -53.69659788,
#          -58.5650539 ])},
#  'LinearRegression_pre_completo_target': {'fit_time': array([0.10294628, 0.09838605, 0.07622337, 0.11068106, 0.09835076]),
#   'score_time': array([0.00724888, 0.00778723, 0.00771499, 0.00798368, 0.00813079]),
#   'test_r2': array([0.45111029, 0.57091417, 0.38387487, 0.57951988, 0.39804129]),
#   'test_neg_mean_absolute_error': array([-42.03726802, -40.89695387, -47.25775997, -42.49541049,
#          -46.10165975]),
#   'test_neg_root_mean_squared_error': array([-53.92681116, -51.73875653, -57.90962844, -53.19756216,
#          -57.99562746])},
#  'Lasso_pre_cat': {'fit_time': array([0.00659013, 0.00741243, 0.00771165, 0.00815201, 0.00683784]),
#   'score_time': array([0.00588059, 0.00469303, 0.00528598, 0.0051899 , 0.00557208]),
#   'test_r2': array([0.44965794, 0.55440409, 0.39410263, 0.58012784, 0.40233332]),
#   'test_neg_mean_absolute_error': array([-43.57969084, -42.07809602, -47.49677201, -43.15317508,
#          -47.18741545]),
#   'test_neg_root_mean_squared_error': array([-53.99810877, -52.72474644, -57.42696318, -53.15909003,
#          -57.7884999 ])},
#  'Lasso_pre_simples': {'fit_time': array([0.00851226, 0.00878239, 0.00933576, 0.00793004, 0.00811577]),
#   'score_time': array([0.005795  , 0.00635076, 0.0054791 , 0.00521636, 0.0054791 ]),
#   'test_r2': array([0.46541546, 0.56024764, 0.38888187, 0.58892906, 0.39796849]),
#   'test_neg_mean_absolute_error': array([-42.93829143, -42.05869226, -47.72324191, -42.40666071,
#          -47.33043551]),
#   'test_neg_root_mean_squared_error': array([-53.21945142, -52.37788926, -57.67384434, -52.59898786,
#          -57.99913431])},
#  'Lasso_pre_completo': {'fit_time': array([0.08724809, 0.08917475, 0.12445736, 0.11194587, 0.09448385]),
#   'score_time': array([0.00701141, 0.00803161, 0.00955009, 0.00659037, 0.00668979]),
#   'test_r2': array([0.44850982, 0.56296381, 0.38882216, 0.57172312, 0.39600107]),
#   'test_neg_mean_absolute_error': array([-43.83134923, -42.35390873, -47.65557448, -43.52982335,
#          -47.49009097]),
#   'test_neg_root_mean_squared_error': array([-54.05440468, -52.2158803 , -57.67666216, -53.68850533,
#          -58.09382648])},
#  'Lasso_pre_completo_target': {'fit_time': array([0.08679032, 0.09951997, 0.08414268, 0.09947515, 0.14337873]),
#   'score_time': array([0.00835872, 0.00733471, 0.00800443, 0.01563072, 0.00911808]),
#   'test_r2': array([-0.00329934, -0.10055968, -0.10315844, -0.02069488, -0.0032381 ]),
#   'test_neg_mean_absolute_error': array([-62.70054926, -71.16706039, -61.60846017, -68.85404765,
#          -62.58286463]),
#   'test_neg_root_mean_squared_error': array([-72.90838209, -82.86110111, -77.48814488, -82.88328716,
#          -74.87104713])},
#  'Lasso_pre_completo_target_hiper': {'fit_time': array([0.13401008, 0.09712505, 0.0792737 , 0.09478641, 0.09966683]),
#   'score_time': array([0.00841522, 0.0071559 , 0.00824928, 0.00764632, 0.00755358]),
#   'test_r2': array([0.46203583, 0.48062253, 0.32098821, 0.57302664, 0.39057008]),
#   'test_neg_mean_absolute_error': array([-42.73430944, -46.19111141, -50.56094944, -44.60681265,
#          -47.29428725]),
#   'test_neg_root_mean_squared_error': array([-53.38741223, -56.92269534, -60.79319604, -53.60673906,
#          -58.35442363])},
#  'Ridge_pre_cat': {'fit_time': array([0.00761986, 0.00738764, 0.00652742, 0.00648141, 0.00638509]),
#   'score_time': array([0.00502062, 0.004812  , 0.0059402 , 0.00563049, 0.0047226 ]),
#   'test_r2': array([0.45177188, 0.57192243, 0.40581572, 0.58771433, 0.39476717]),
#   'test_neg_mean_absolute_error': array([-43.07969088, -41.56684994, -46.77311637, -41.94249401,
#          -47.23257592]),
#   'test_neg_root_mean_squared_error': array([-53.89430171, -51.67793322, -56.86917116, -52.67664638,
#          -58.15313561])},
#  'Ridge_pre_simples': {'fit_time': array([0.00827098, 0.00861263, 0.01685667, 0.0159657 , 0.00858259]),
#   'score_time': array([0.0053246 , 0.0052247 , 0.01314449, 0.0143671 , 0.00508237]),
#   'test_r2': array([0.4533428 , 0.57246964, 0.40532271, 0.58744155, 0.39403642]),
#   'test_neg_mean_absolute_error': array([-43.00489453, -41.55899504, -46.808447  , -41.92108619,
#          -47.25968591]),
#   'test_neg_root_mean_squared_error': array([-53.81703054, -51.64489285, -56.89275914, -52.69406945,
#          -58.18823174])},
#  'Ridge_pre_completo': {'fit_time': array([0.09094787, 0.09462929, 0.07498384, 0.0908916 , 0.09394145]),
#   'score_time': array([0.00868487, 0.0064261 , 0.00659561, 0.00676012, 0.00701237]),
#   'test_r2': array([0.44133092, 0.57219138, 0.4060797 , 0.57179922, 0.3897379 ]),
#   'test_neg_mean_absolute_error': array([-43.71900409, -41.92023036, -46.58954887, -42.81276827,
#          -47.65795699]),
#   'test_neg_root_mean_squared_error': array([-54.40508763, -51.66169672, -56.85653703, -53.68373503,
#          -58.39425206])},
#  'Ridge_pre_completo_target': {'fit_time': array([0.09144187, 0.11452723, 0.08395767, 0.09594989, 0.09663773]),
#   'score_time': array([0.00922966, 0.00740957, 0.00686502, 0.00843906, 0.00746989]),
#   'test_r2': array([0.44992048, 0.56999281, 0.37907057, 0.57941714, 0.40158231]),
#   'test_neg_mean_absolute_error': array([-42.21926626, -40.93819503, -47.48322203, -42.4639736 ,
#          -45.85690049]),
#   'test_neg_root_mean_squared_error': array([-53.98522735, -51.79427497, -58.1349683 , -53.20406134,
#          -57.82479626])},
#  'Ridge_pre_completo_target_hiper': {'fit_time': array([0.08702636, 0.09886694, 0.07704186, 0.09220052, 0.09819269]),
#   'score_time': array([0.00714779, 0.0072782 , 0.00719523, 0.00759387, 0.00820684]),
#   'test_r2': array([0.45097704, 0.57084396, 0.38332041, 0.57951397, 0.39853164]),
#   'test_neg_mean_absolute_error': array([-42.05951364, -40.90020502, -47.28556789, -42.49238976,
#          -46.06877134]),
#   'test_neg_root_mean_squared_error': array([-53.93335651, -51.74298972, -57.9356797 , -53.19793636,
#          -57.97200117])},
#  'ElasticNet_pre_cat': {'fit_time': array([0.00654697, 0.00728202, 0.00858569, 0.00742412, 0.00759888]),
#   'score_time': array([0.00485754, 0.00455308, 0.00493503, 0.00489283, 0.00473928]),
#   'test_r2': array([0.42665752, 0.52612987, 0.35513845, 0.56395062, 0.391895  ]),
#   'test_neg_mean_absolute_error': array([-44.80674051, -43.29672327, -49.52519617, -44.81718443,
#          -47.50122732]),
#   'test_neg_root_mean_squared_error': array([-55.11492959, -54.37178213, -59.24470733, -54.17349262,
#          -58.29095739])},
#  'ElasticNet_pre_simples': {'fit_time': array([0.00969148, 0.01366472, 0.00882936, 0.00855327, 0.00812817]),
#   'score_time': array([0.00804377, 0.00800538, 0.00565815, 0.00533843, 0.00532937]),
#   'test_r2': array([0.45027414, 0.50810119, 0.36545236, 0.55713242, 0.37611739]),
#   'test_neg_mean_absolute_error': array([-44.18981668, -45.08570118, -49.04981948, -45.89216586,
#          -49.01035069]),
#   'test_neg_root_mean_squared_error': array([-53.96787042, -55.39643102, -58.76901802, -54.59538599,
#          -59.04230979])},
#  'ElasticNet_pre_completo': {'fit_time': array([0.08937359, 0.09557486, 0.07514954, 0.08805323, 0.09077549]),
#   'score_time': array([0.00731516, 0.00744796, 0.00687623, 0.00669408, 0.00699282]),
#   'test_r2': array([0.43841474, 0.50474321, 0.36034032, 0.54133843, 0.372339  ]),
#   'test_neg_mean_absolute_error': array([-44.91783348, -45.67638711, -49.15424121, -46.8376918 ,
#          -49.44210668]),
#   'test_neg_root_mean_squared_error': array([-54.5468964 , -55.58519315, -59.00527048, -55.56037608,
#          -59.22082757])},
#  'ElasticNet_pre_completo_target': {'fit_time': array([0.08960962, 0.104105  , 0.07967734, 0.11355853, 0.09652758]),
#   'score_time': array([0.00776935, 0.00755072, 0.00755215, 0.00728559, 0.00678229]),
#   'test_r2': array([ 0.0549001 , -0.05283876, -0.00838641,  0.03505005,  0.08195681]),
#   'test_neg_mean_absolute_error': array([-60.82835503, -69.35626099, -59.29631074, -67.29214297,
#          -59.8493292 ]),
#   'test_neg_root_mean_squared_error': array([-70.76215591, -81.04474011, -74.08491894, -80.58818828,
#          -71.62150731])},
#  'ElasticNet_pre_completo_target_hiper': {'fit_time': array([0.08743238, 0.09514713, 0.07470179, 0.10194945, 0.0977459 ]),
#   'score_time': array([0.00715446, 0.00711298, 0.00682688, 0.00704384, 0.00810361]),
#   'test_r2': array([0.45793764, 0.50871705, 0.32492906, 0.58913771, 0.39851209]),
#   'test_neg_mean_absolute_error': array([-42.78461171, -44.96448557, -50.48739439, -43.28882969,
#          -46.75937779]),
#   'test_neg_root_mean_squared_error': array([-53.59037831, -55.36174187, -60.61652328, -52.58563716,
#          -57.97294329])}}

# %%
df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                                    model  fit_time score_time   test_r2  \
# 0                         DummyRegressor  0.001659   0.002294 -0.011963
# 1                         DummyRegressor  0.001451   0.001799 -0.026978
# 2                         DummyRegressor  0.001318   0.003402 -0.015304
# 3                         DummyRegressor  0.001744   0.002453 -0.000212
# 4                         DummyRegressor  0.002098   0.002269 -0.042316
# ..                                   ...       ...        ...       ...
# 95  ElasticNet_pre_completo_target_hiper  0.087432   0.007154  0.457938
# 96  ElasticNet_pre_completo_target_hiper  0.095147   0.007113  0.508717
# 97  ElasticNet_pre_completo_target_hiper  0.074702   0.006827  0.324929
# 98  ElasticNet_pre_completo_target_hiper  0.101949   0.007044  0.589138
# 99  ElasticNet_pre_completo_target_hiper  0.097746   0.008104  0.398512
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                    -64.006461                       -73.222493     0.003954
# 1                    -70.577936                       -80.043187     0.003249
# 2                    -59.829545                       -74.338597      0.00472
# 3                    -70.053929                       -82.047452     0.004196
# 4                    -65.425655                       -76.315297     0.004368
# ..                          ...                              ...          ...
# 95                   -42.784612                       -53.590378     0.094587
# 96                   -44.964486                       -55.361742      0.10226
# 97                   -50.487394                       -60.616523     0.081529
# 98                    -43.28883                       -52.585637     0.108993
# 99                   -46.759378                       -57.972943      0.10585
#
# [100 rows x 7 columns]

# %%
#Vamos estilizar e colocar cada modelo numa cor diferente

# %%
df_resultados["model"].str.split("_")#Se viu que ele criou uma lista porem a gente só quer a primeira posição
# Out:
# 0                               [DummyRegressor]
# 1                               [DummyRegressor]
# 2                               [DummyRegressor]
# 3                               [DummyRegressor]
# 4                               [DummyRegressor]
#                          ...
# 95    [ElasticNet, pre, completo, target, hiper]
# 96    [ElasticNet, pre, completo, target, hiper]
# 97    [ElasticNet, pre, completo, target, hiper]
# 98    [ElasticNet, pre, completo, target, hiper]
# 99    [ElasticNet, pre, completo, target, hiper]
# Name: model, Length: 100, dtype: object

# %%
df_resultados["model"].str.split("_")[0] # se viu que ainda ele não entendeu, porque ele só pegou a primeira posição do dic e não a primeira de todas as linhas
# Out:
# ['DummyRegressor']

# %%
df_resultados["model"].str.split("_").str[0]#Aqui você esta falando que você quer um metedo de strings dentro de um df
# Out:
# 0     DummyRegressor
# 1     DummyRegressor
# 2     DummyRegressor
# 3     DummyRegressor
# 4     DummyRegressor
#            ...
# 95        ElasticNet
# 96        ElasticNet
# 97        ElasticNet
# 98        ElasticNet
# 99        ElasticNet
# Name: model, Length: 100, dtype: object

# %%
df_resultados["model_group"]= df_resultados["model"].str.split("_").str[0]
df_resultados
# Out:
#                                    model  fit_time score_time   test_r2  \
# 0                         DummyRegressor  0.001659   0.002294 -0.011963
# 1                         DummyRegressor  0.001451   0.001799 -0.026978
# 2                         DummyRegressor  0.001318   0.003402 -0.015304
# 3                         DummyRegressor  0.001744   0.002453 -0.000212
# 4                         DummyRegressor  0.002098   0.002269 -0.042316
# ..                                   ...       ...        ...       ...
# 95  ElasticNet_pre_completo_target_hiper  0.087432   0.007154  0.457938
# 96  ElasticNet_pre_completo_target_hiper  0.095147   0.007113  0.508717
# 97  ElasticNet_pre_completo_target_hiper  0.074702   0.006827  0.324929
# 98  ElasticNet_pre_completo_target_hiper  0.101949   0.007044  0.589138
# 99  ElasticNet_pre_completo_target_hiper  0.097746   0.008104  0.398512
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds  \
# 0                    -64.006461                       -73.222493     0.003954
# 1                    -70.577936                       -80.043187     0.003249
# 2                    -59.829545                       -74.338597      0.00472
# 3                    -70.053929                       -82.047452     0.004196
# 4                    -65.425655                       -76.315297     0.004368
# ..                          ...                              ...          ...
# 95                   -42.784612                       -53.590378     0.094587
# 96                   -44.964486                       -55.361742      0.10226
# 97                   -50.487394                       -60.616523     0.081529
# 98                    -43.28883                       -52.585637     0.108993
# 99                   -46.759378                       -57.972943      0.10585
#
#        model_group
# 0   DummyRegressor
# 1   DummyRegressor
# 2   DummyRegressor
# 3   DummyRegressor
# 4   DummyRegressor
# ..             ...
# 95      ElasticNet
# 96      ElasticNet
# 97      ElasticNet
# 98      ElasticNet
# 99      ElasticNet
#
# [100 rows x 8 columns]

# %%
df_resultados.head(20)
# Out:
#                             model  fit_time score_time   test_r2  \
# 0                  DummyRegressor  0.001659   0.002294 -0.011963
# 1                  DummyRegressor  0.001451   0.001799 -0.026978
# 2                  DummyRegressor  0.001318   0.003402 -0.015304
# 3                  DummyRegressor  0.001744   0.002453 -0.000212
# 4                  DummyRegressor  0.002098   0.002269 -0.042316
# 5        LinearRegression_pre_cat  0.012212   0.004699    0.4523
# 6        LinearRegression_pre_cat  0.007972    0.00534  0.573703
# 7        LinearRegression_pre_cat   0.00665   0.004559  0.406833
# 8        LinearRegression_pre_cat  0.005885   0.004589  0.588126
# 9        LinearRegression_pre_cat  0.006434   0.004767  0.391319
# 10   LinearRegression_pre_simples  0.008724   0.005628    0.4523
# 11   LinearRegression_pre_simples  0.008171   0.005377  0.573703
# 12   LinearRegression_pre_simples  0.008152   0.005725  0.406833
# 13   LinearRegression_pre_simples   0.00753   0.005955  0.588126
# 14   LinearRegression_pre_simples   0.00808    0.00572  0.391319
# 15  LinearRegression_pre_completo  0.085422   0.006686  0.441826
# 16  LinearRegression_pre_completo  0.092677   0.007018  0.572306
# 17  LinearRegression_pre_completo  0.075532   0.006994  0.408224
# 18  LinearRegression_pre_completo   0.09391   0.007535  0.571594
# 19  LinearRegression_pre_completo  0.093616   0.007888  0.386163
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds  \
# 0                    -64.006461                       -73.222493     0.003954
# 1                    -70.577936                       -80.043187     0.003249
# 2                    -59.829545                       -74.338597      0.00472
# 3                    -70.053929                       -82.047452     0.004196
# 4                    -65.425655                       -76.315297     0.004368
# 5                    -42.980798                        -53.86835     0.016911
# 6                    -41.530714                        -51.57032     0.013312
# 7                    -46.702453                       -56.820458     0.011209
# 8                    -41.895672                       -52.650369     0.010474
# 9                    -47.423857                       -58.318555     0.011201
# 10                   -42.980798                       -53.868349     0.014352
# 11                   -41.530714                        -51.57032     0.013548
# 12                   -46.702453                       -56.820458     0.013877
# 13                   -41.895672                       -52.650369     0.013484
# 14                   -47.423856                       -58.318554       0.0138
# 15                   -43.642653                       -54.380967     0.092108
# 16                    -41.89732                       -51.654796     0.099695
# 17                   -46.450666                        -56.75382     0.082526
# 18                    -42.77941                       -53.696598     0.101445
# 19                   -47.844017                       -58.565054     0.101504
#
#          model_group
# 0     DummyRegressor
# 1     DummyRegressor
# 2     DummyRegressor
# 3     DummyRegressor
# 4     DummyRegressor
# 5   LinearRegression
# 6   LinearRegression
# 7   LinearRegression
# 8   LinearRegression
# 9   LinearRegression
# 10  LinearRegression
# 11  LinearRegression
# 12  LinearRegression
# 13  LinearRegression
# 14  LinearRegression
# 15  LinearRegression
# 16  LinearRegression
# 17  LinearRegression
# 18  LinearRegression
# 19  LinearRegression

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 8), sharex=True)

comparar_metricas = [
    "time_seconds",
    "test_r2",
    "test_neg_mean_absolute_error",
    "test_neg_root_mean_squared_error",
]

nomes_metricas = [
    "Tempo (s)",
    "R2",
    "MAE",
    "RMSE"
]

for ax, metrica, nome in zip(axs.flatten(), comparar_metricas, nomes_metricas):
    sns.boxplot(
        x="model",
        y=metrica,
        data=df_resultados,
        ax=ax,
        showmeans=True,
        hue = "model_group"
    )
    ax.set_title(nome)
    ax.set_ylabel(nome)
    ax.tick_params(axis="x", rotation=90)

    legend = ax.get_legend()
    labels = [text.get_text() for text in legend.get_texts()]
    ax.get_legend().remove()

fig.legend(
    handles=legend.legend_handles,
    labels = labels,
    loc="upper center",
    ncol=5,
    bbox_to_anchor=(0.5, 1.05)
)

plt.tight_layout()
plt.show()
